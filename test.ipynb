# %%
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import rdDistGeom
from rdkit.Chem import rdMolAlign
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem import rdMolTransforms
from rdkit.Chem import rdForceFieldHelpers

from rdkit.Chem import PyMol
import copy
import numpy as np

# %%
m = Chem.MolFromSmiles("C[C@@H](C(=O)N[C@@H](C)C(=O)O)N")
m

# %%
m2 = Chem.AddHs(m)
m2

# %%
AllChem.EmbedMolecule(m2)
m2

# %%
rotatable_bonds = Chem.rdMolDescriptors.CalcNumRotatableBonds(m2)
rotatable_bonds
# Out:
# 6

# %%
RotatableBond = Chem.MolFromSmarts('[!$(*#*)&!D1]-&!@[!$(*#*)&!D1]')
m.GetSubstructMatches(RotatableBond)
# Out:
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# Cell In[14], line 4
#       1 RotatableBond = Chem.MolFromSmarts('[!$(*#*)&!D1]-&!@[!$(*#*)&!D1]')
#       2 m.GetSubstructMatches(RotatableBond)
# ----> 4 Chem.rdMolTransforms.SetAngleDeg(m2, 0,1,2, 30.0)
#
# ArgumentError: Python argument types in
#     rdkit.Chem.rdMolTransforms.SetAngleDeg(Mol, int, int, int, float)
# did not match C++ signature:
#     SetAngleDeg(RDKit::Conformer {lvalue} conf, unsigned int iAtomId, unsigned int jAtomId, unsigned int kAtomId, double value)
